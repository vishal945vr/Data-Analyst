# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib as plt

# %%
data=pd.read_excel("vishal.xlsx")
print(data)
# Out:
#        index             Order ID  Cust ID Gender  Age       Date     Status  \
# 0          1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1          2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2          3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3          4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4          5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
# ...      ...                  ...      ...    ...  ...        ...        ...
# 31042  31043  405-4724097-1016369  4724097      M   60 2022-01-06  Delivered
# 31043  31044  405-4724097-1016369  4724097      M   34 2022-01-06  Delivered
# 31044  31045  408-3572295-5992330  3572295      M   29 2022-01-06  Delivered
# 31045  31046  405-1423498-9705162  1423498      M   46 2022-01-06  Delivered
# 31046  31047  408-4694875-8249153  4694875      M   36 2022-01-06  Delivered
#
# ...

# %%
data.drop_duplicates()
# Out:
#        index             Order ID  Cust ID Gender  Age       Date     Status  \
# 0          1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1          2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2          3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3          4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4          5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
# ...      ...                  ...      ...    ...  ...        ...        ...
# 31042  31043  405-4724097-1016369  4724097      M   60 2022-01-06  Delivered
# 31043  31044  405-4724097-1016369  4724097      M   34 2022-01-06  Delivered
# 31044  31045  408-3572295-5992330  3572295      M   29 2022-01-06  Delivered
# 31045  31046  405-1423498-9705162  1423498      M   46 2022-01-06  Delivered
# 31046  31047  408-4694875-8249153  4694875      M   36 2022-01-06  Delivered
#
# ...

# %%
data.head(10)
# Out:
#    index             Order ID  Cust ID Gender  Age       Date     Status  \
# 0      1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1      2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2      3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3      4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4      5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
# 5      6  407-1298130-0368305  1298130    Men   49 2022-12-04  Delivered
# 6      7  407-1298130-0368305  1298130      W   23 2022-12-04  Delivered
# 7      8  171-5561216-3398711  5561216      W   70 2022-12-04  Delivered
# 8      9  408-2935263-2935550  2935263      W   75 2022-12-04  Delivered
# 9     10  404-2648970-9042715  2648970      W   43 2022-12-04  Delivered
#
#    Channel                       SKU       Category Size  Qty currency  \
# 0    Myntra  JNE1233-BLUE-KR-031-XXL          kurta  XXL    1      INR
# ...

# %%
data.describe()
# Out:
#              index       Cust ID           Age                           Date  \
# count  31047.00000  3.104700e+04  31047.000000                          31047
# mean   15524.00000  4.936824e+06     39.496570  2022-06-15 06:41:39.719779584
# min        1.00000  8.950000e+02     18.000000            2022-01-04 00:00:00
# 25%     7762.50000  2.416471e+06     28.000000            2022-03-06 00:00:00
# 50%    15524.00000  4.909885e+06     37.000000            2022-06-06 00:00:00
# 75%    23285.50000  7.454182e+06     47.000000            2022-09-06 00:00:00
# max    31047.00000  9.999233e+06     78.000000            2022-12-06 00:00:00
# std     8962.64124  2.900678e+06     15.117233                            NaN
#
#              Amount  ship-postal-code
# count  31047.000000      31047.000000
# mean     682.074822     460474.587206
# min      229.000000     110001.000000
# 25%      486.000000     313001.000000
# 50%      646.000000     500028.000000
# ...

# %%
data.isnull().sum()
# Out:
# index               0
# Order ID            0
# Cust ID             0
# Gender              0
# Age                 0
# Date                0
# Status              0
# Channel             0
# SKU                 0
# Category            0
# Size                0
# Qty                 0
# currency            0
# Amount              0
# ship-city           0
# ship-state          0
# ship-postal-code    0
# ship-country        0
# B2B                 0
# dtype: int64

# %%
data["Amount"].max()
# Out:
# np.int64(3036)

# %%
data["Amount"].min()
# Out:
# np.int64(229)

# %%
data["Amount"].count()
# Out:
# np.int64(31047)

# %%
data["Amount"].mean()
# Out:
# np.float64(682.0748220439978)

# %%
data["Amount"].std()
# Out:
# np.float64(268.58217349679035)

# %%
data["Amount"].var()
# Out:
# np.float64(72136.38392025999)

# %%
data.sort_values("Size")
# Out:
#        index             Order ID  Cust ID Gender  Age       Date     Status  \
# 31046  31047  408-4694875-8249153  4694875      M   36 2022-01-06  Delivered
# 14088  14089  171-9228782-5960315  9228782  Women   33 2022-08-05  Delivered
# 14087  14088  405-0398437-4153119   398437    Men   34 2022-08-05  Delivered
# 14078  14079  402-8082251-3461936  8082251    Men   27 2022-08-05  Delivered
# 2884    2885  407-8712882-7697105  8712882    Men   33 2022-09-04  Delivered
# ...      ...                  ...      ...    ...  ...        ...        ...
# 18065  18066  405-0035934-6441906    35934  Women   33 2022-04-05  Delivered
# 18062  18063  402-3404108-9553922  3404108    Men   47 2022-04-05  Delivered
# 18057  18058  404-4069836-7434734  4069836  Women   76 2022-04-05  Delivered
# 17034  17035  407-2581427-8109110  2581427    Men   36 2022-05-05  Delivered
# 15523  15524  408-4065581-7878715  4065581    Men   49 2022-06-05  Delivered
#
# ...

# %%
data["ship-city"]=data["ship-city"].replace("MOHALI","NODIA")

# %%
data.head(5)
# Out:
#    index             Order ID  Cust ID Gender  Age       Date     Status  \
# 0      1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1      2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2      3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3      4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4      5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
#
#   Channel                       SKU Category Size Qty currency  Amount  \
# 0   Myntra  JNE1233-BLUE-KR-031-XXL    kurta  XXL   1      INR     376
# 1     Ajio           SET414-KR-NP-L      Set    L   1      INR    1449
# 2   Myntra           SET261-KR-PP-S      Set    S   1      INR     453
# 3   Amazon           SET110-KR-PP-M      Set    M   1      INR     729
# 4   Myntra         JNE2294-KR-A-XXL    kurta  XXL   1      INR     544
#
#    ship-city   ship-state  ship-postal-code ship-country    B2B
# ...

# %%
data["ship-state"]=data["ship-state"].replace("PUNJAB","PB")
data["ship-state"]=data["ship-state"].replace("WEST BENGAL","WB")
data["ship-state"]=data["ship-state"].replace("ANDHRA PRADESH","AP")
data["ship-state"]=data["ship-state"].replace("UTTAR PRADESH","UP")
data["ship-state"]=data["ship-state"].replace("MAHARASHTRA","MT")





data.head(5)
# Out:
#    index             Order ID  Cust ID Gender  Age       Date     Status  \
# 0      1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1      2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2      3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3      4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4      5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
#
#   Channel                       SKU Category Size Qty currency  Amount  \
# 0   Myntra  JNE1233-BLUE-KR-031-XXL    kurta  XXL   1      INR     376
# 1     Ajio           SET414-KR-NP-L      Set    L   1      INR    1449
# 2   Myntra           SET261-KR-PP-S      Set    S   1      INR     453
# 3   Amazon           SET110-KR-PP-M      Set    M   1      INR     729
# 4   Myntra         JNE2294-KR-A-XXL    kurta  XXL   1      INR     544
#
#    ship-city  ship-state  ship-postal-code ship-country    B2B
# ...

# %% [markdown]
# #Graphs

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
sns.barplot(x="Size",y="Amount",data=data,hue="Gender",)
# Out:
# <Axes: xlabel='Size', ylabel='Amount'>

# %%
plt.figure(figsize=(12, 50))
sns.displot(x="Category",data=data,rug=True)

plt.show()

# %%
sns.stripplot(x="Size",y="Category",data=data)
xticklable=False

# %%
sns.scatterplot(x="Age",y="Size",data=data,)
plt.show()

# %%
sns.violinplot(x="Qty",y="Category",data=data)
plt.show()

# %%
sns.histplot(x="Size",data=data)
plt.show()

# %% [markdown]
# #conclusion

# %% [markdown]
# Conclusion
# The analysis of the e-commerce sales data has provided valuable insights into customer behavior, product performance, and potential areas for business improvement. The key findings from the analysis are:
#
# Data Consistency and Quality: Ensuring consistent and clean data is crucial for accurate analysis. Standardizing city and state names and handling missing values are essential steps in data preprocessing.
#
# Descriptive Statistics: The statistical summary of sales amounts reveals the distribution and central tendencies of transactions, helping to identify high-value customers and understand overall sales performance.
#
# Purchase Patterns: Visualizations such as bar plots, distribution plots, and scatter plots highlight the relationships between different variables like size, amount, gender, age, and category. These patterns are instrumental in shaping targeted marketing strategies and optimizing product offerings.
#
# Marketing Strategies: Personalized marketing based on gender and age-specific targeting can significantly enhance customer engagement and increase sales. Understanding the preferences and behaviors of different customer segments allows for more effective and efficient marketing efforts.
#
# Inventory Management: Insights from the data help in optimizing inventory levels by aligning stock with the most popular sizes and categories. This ensures better inventory turnover and reduces the risk of stockouts or overstocking.
#
# Further Analysis: Advanced techniques like correlation analysis, predictive modeling, and customer segmentation can provide deeper insights and more precise strategies for sales forecasting, customer targeting, and overall business planning.
#
# Recommendations for Action
# Data Standardization: Continuously monitor and standardize data entries to maintain high data quality.
# Customer Targeting: Implement targeted marketing campaigns based on the insights from gender and age analysis.
# Inventory Optimization: Adjust inventory levels based on the size and category trends observed in the data.
# Advanced Analytics: Invest in advanced analytics techniques to further refine business strategies and enhance decision-making.
# By following these recommendations, the business can leverage data-driven insights to improve marketing effectiveness, optimize inventory management, and ultimately drive higher sales and customer satisfaction.
